# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
file_id = 'https://docs.google.com/spreadsheets/d/1je63pR15mFVim7kTCkQCsJg6Af5Xdpsc/edit?usp=drive_link&ouid=113544346438304110369&rtpof=true&sd=true'  # Replace with your actual file ID
file_path = f'/content/gdrive/MyDrive/Finance project Python/Copy1.xlsx'  # Replace with your actual file ID


df = pd.read_excel(file_path)

# %%
from google.colab import files

# Drop rows with missing values in any commodity column
df_cleaned = df.dropna(subset=['S 1 COMB Comdty (USD)  (L1)', 'SM1 Comdty (USD)  (R2)', 'BO1 Comdty (USD)  (R1)', 'RS1 Comdty (USD)  (R2)', 'ZRR1 Comdty (USD)  (R2)', 'KO1 Comdty (USD)  (R3)'], how='any')

# Save the cleaned data to a new Excel file
cleaned_file_name = 'cleaned_dataofSixPrices.xlsx'
df_cleaned.to_excel(cleaned_file_name, index=False)

# Download the cleaned file
files.download(cleaned_file_name)
